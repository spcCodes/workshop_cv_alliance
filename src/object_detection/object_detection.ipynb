# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/alliance_university/object_detection/datasets.zip -d /content/drive/MyDrive/alliance_university/object_detection
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/datasets/labels/train/003960_jpg.rf.1d5ca7f744183cd314fa162eec7cf80c.txt
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/__MACOSX/datasets/labels/train/._003960_jpg.rf.1d5ca7f744183cd314fa162eec7cf80c.txt
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/datasets/labels/train/003607_jpg.rf.a7a71d361cf1e0c2a659feca5e8f1c13.txt
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/__MACOSX/datasets/labels/train/._003607_jpg.rf.a7a71d361cf1e0c2a659feca5e8f1c13.txt
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/datasets/labels/train/003679_jpg.rf.5dd651b1716565b9dd49b6a742496aea.txt
#   inflating: /content/drive/MyDrive/alliance_university/object_detection/__MACOSX/datasets/labels/train/._003679_jpg.rf.5dd651b1716565b9dd49b6a742496aea.txt
# ...

# %%
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 8.8 MB/s eta 0:00:00

# %%
# !python /content/drive/MyDrive/alliance_university/object_detection/train.py
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 290MB/s]
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# !mv /content/runs /content/drive/MyDrive/alliance_university/object_detection
